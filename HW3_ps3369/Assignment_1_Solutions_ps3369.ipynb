# %%
from __future__ import print_function
__author__= 'fbb'
import numpy as np
import pylab as pl
import pandas as pd
from scipy import stats
# this package sets up pretty plots
from scipy.optimize import curve_fit, minimize
import matplotlib.mlab as mlab
    
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['e']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
#chi-Square distribution
cd = {}
cd['chisq'] = {} 
mymean=100
df = mymean
#and do it in a for loop. not pythonic, but easily readable
mysize = range(11,2000,20)

for n in mysize:
    cd['chisq'][n] = np.random.chisquare(df, size = n)
nd.keys()
#print(nd['normal'].mean(),nd['normal'].std())
cd['chisq']['means'] = {}
for nn in cd['chisq']:
    if not type(nn) == str:
        cd['chisq']['means'][nn] = cd['chisq'][nn].mean()
        pl.title("ChiSquare Distribution", fontsize=20)
        pl.plot(nn, cd['chisq']['means'][nn], 'o')
        pl.plot([min(mysize), max(mysize)], [df, df], 'k')
        pl.xlabel('sample size', fontsize = 18)
        pl.ylabel('Sample mean', fontsize = 18)
        
allmeans = cd['chisq']['means'].values()
pl.figure(figsize=(5, 5))
pl.hist(allmeans,bins=30)
pl.title("ChiSquare Distribution", fontsize=10)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### <center> ChiSquare:  Sample mean against the sample siz N( $10 <N <2000$) </center>

# %%
#normal distribution
nd = {}
nd['normal'] = {} 
mymean=100
df = mymean
#and do it in a for loop. not pythonic, but easily readable
mysize = range(11,2000,20)

for n in mysize:
    nd['normal'][n] = np.random.normal(df, size = n)
nd.keys()
#print(nd['normal'].mean(),nd['normal'].std())
nd['normal']['means'] = {}
for nn in nd['normal']:
    if not type(nn) == str:
        nd['normal']['means'][nn] = nd['normal'][nn].mean()
        pl.title("Normal Distribution", fontsize=20)
        pl.plot(nn, nd['normal']['means'][nn], 'o')
        pl.plot([min(mysize), max(mysize)], [df, df], 'k')
        
allmeans = nd['normal']['means'].values()
pl.figure(figsize=(5, 5))
pl.hist(allmeans,bins=30)
pl.title("Normal Distribution", fontsize=10)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### Normal: Sample mean against the sample siz N( $10 <N <2000$)

# %%
#Binomial distribution
bd = {}
bd['binomial'] = {} 

#and do it in a for loop. not pythonic, but easily readable
mysize = range(11,2000,20)

for n in mysize:
    bd['binomial'][n] = np.random.binomial(200,0.5,size = n)
#pd.keys()
#print(nd['normal'].mean(),nd['normal'].std())
bd['binomial']['means'] = {}
for nn in bd['binomial']:
    if not type(nn) == str:
        bd['binomial']['means'][nn] = bd['binomial'][nn].mean()
        pl.title("Binomial Distribution", fontsize=20)
        pl.plot(nn, bd['binomial']['means'][nn], 'o')
        pl.plot([min(mysize), max(mysize)], [df, df], 'k')
        
allmeans = bd['binomial']['means'].values()
pl.figure(figsize=(5, 5))
pl.hist(allmeans,bins=30)
pl.title("Binomial Distribution", fontsize=10)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### Binomial: Sample mean against the sample siz N( $10 <N <2000$)

# %%
#Poisson distribution
pd={}
pd['poisson'] = {} 

#and do it in a for loop. not pythonic, but easily readable
mysize = range(11,2000,20)

for n in mysize:
    pd['poisson'][n] = np.random.poisson(df, size = n)
pd.keys()
#print(nd['normal'].mean(),nd['normal'].std())
pd['poisson']['means'] = {}
for nn in pd['poisson']:
    if not type(nn) == str:
        pd['poisson']['means'][nn] = pd['poisson'][nn].mean()
        pl.title("Binomial Distribution", fontsize=10)
        pl.plot(nn, pd['poisson']['means'][nn], 'o')
        pl.plot([min(mysize), max(mysize)], [df, df], 'k')
allmeans =pd['poisson']['means'].values()
pl.figure(figsize=(5, 5))
pl.hist(allmeans,bins=30)
pl.title("Poisson Distribution", fontsize=10)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### Poisson: Sample mean against the sample siz N( $10 <N <2000$)

# %%
#Gamma distribution
gd={}
gd['gamma'] = {} 

#and do it in a for loop. not pythonic, but easily readable
mysize = range(11,2000,20)

for n in mysize:
    gd['gamma'][n] = np.random.gamma(200,0.5, size = n)
pd.keys()
#print(nd['normal'].mean(),nd['normal'].std())
gd['gamma']['means'] = {}
for nn in gd['gamma']:
    if not type(nn) == str:
        gd['gamma']['means'][nn] = gd['gamma'][nn].mean()
        pl.title("Gamma Distribution", fontsize=10)
        pl.plot(nn, gd['gamma']['means'][nn], 'o')
        pl.plot([min(mysize), max(mysize)], [df, df], 'k')
allmeans =gd['gamma']['means'].values()
pl.figure(figsize=(5, 5))
pl.hist(allmeans,bins=30)
pl.title("Gamma Distribution", fontsize=10)
pl.xlabel('sample mean', fontsize = 18)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### Gamma: Sample mean against the sample siz N( $10 <N <2000$)

# %%
a= nd['normal']['means'].values()
b= cd['chisq']['means'].values()
c= pd['poisson']['means'].values()
d= bd['binomial']['means'].values()
e= gd['gamma']['means'].values()
a.extend(b)
a.extend(c)
a.extend(d)
a.extend(e)
len(a)

pl.figure(figsize=(8, 8))
pl.hist(a,bins=30)
pl.title("All Sample Means", fontsize=10)
pl.xlabel('all Sample Means', fontsize = 14)
pl.ylabel('N', fontsize = 18)

# %% [markdown]
# ### All Sample Means against the Size

# %%
(mu, sigma) = stats.norm.fit(a)
pl.figure(figsize= (10,10))

n, bins, patches = plt.hist(a, 60, normed=True, facecolor='green', alpha=0.75, )


y = mlab.normpdf(bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)
plt.title("Fit Results: mu = %0.2f, std = %0.2f"  % (mu, sigma))
plt.xlabel('Sample Mean', fontsize = 14)
plt.ylabel('Probablity', fontsize = 14)
# print("fimu,sigma)

# %% [markdown]
# ### <center> Fitted Gaussian curve on all sample means </center>
